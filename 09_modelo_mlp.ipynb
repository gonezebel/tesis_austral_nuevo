# %%
import os
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neural_network import MLPClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    classification_report, confusion_matrix, ConfusionMatrixDisplay,
    roc_curve, auc, accuracy_score, precision_recall_curve, average_precision_score,
    recall_score, make_scorer
)
from sklearn.preprocessing import label_binarize
from matplotlib.backends.backend_pdf import PdfPages
from datetime import datetime
from pathlib import Path
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.combine import SMOTEENN
from imblearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold, cross_validate

# %%
# === CONFIGURACION ===
REPO_ROOT = Path(".").resolve()
RUN_ID = datetime.today().strftime("%Y%m%d")

INPUT_BASE = REPO_ROOT / "data" / "intermediate" / "05_seleccion"
OUTPUT_BASE = REPO_ROOT / "reports" / "10_modelo_redmlp" / RUN_ID

MODEL_NAME = "RedMLP"
INTENTO = 10  # Cambia segun version
N_SPLITS = 3  # Igual que LightGBM pero con red liviana
TARGET_CLASS = None  # usa el minimo de nivel_triage si es None
MAX_ITER = 60  # Epocas cortas + early stopping para no saturar
LEARNING_RATE_INIT = 0.002
fecha_actual = datetime.today().strftime("%Y-%m-%d")

if not INPUT_BASE.exists():
    raise FileNotFoundError("No se encontro data/intermediate/05_seleccion")

input_candidates = sorted([p for p in INPUT_BASE.iterdir() if p.is_dir()])
if not input_candidates:
    raise FileNotFoundError("No se encontraron subcarpetas en data/intermediate/05_seleccion")
INPUT_PATH = input_candidates[-1]
print(f"Usando input: {INPUT_PATH}")

OUTPUT_PATH = OUTPUT_BASE / f"{MODEL_NAME}_{INTENTO:02d}_{fecha_actual}"
OUTPUT_PATH.mkdir(parents=True, exist_ok=True)

BALANCE_METHODS = {
    "NONE": None,
    "SMOTE": SMOTE(random_state=42),
    "UNDER": RandomUnderSampler(random_state=42),
    "SMOTEENN": SMOTEENN(random_state=42)
}

metricas_totales = []

# Detectar variantes de datasets
variantes_X = sorted([f for f in os.listdir(INPUT_PATH) if f.startswith("X_train")])
# Out:
# Usando input: C:\Users\Gonzalo\Documents\GitHub\TesisAustral\tesis_austral_2\data\intermediate\05_seleccion\04_2026_01_12

# %%
best_score = -1.0
best_info = None


def build_mlp(num_classes: int):
    "MLP sencillo con escalado previo, pensado para muchas variantes."
    hidden = (96, 48) if num_classes > 2 else (64, 32)
    return MLPClassifier(
        hidden_layer_sizes=hidden,
        activation="relu",
        solver="adam",
        learning_rate_init=LEARNING_RATE_INIT,
        max_iter=MAX_ITER,
        batch_size=128,
        alpha=1e-4,
        early_stopping=True,
        n_iter_no_change=6,
        validation_fraction=0.12,
        shuffle=True,
        random_state=42,
        verbose=False,
    )


def build_pipeline(balancer, num_classes: int):
    steps = []
    if balancer is not None:
        steps.append(("balance", balancer))
    # with_mean=False evita problemas si algun set es esparso; mantiene liviano
    steps.append(("scale", StandardScaler(with_mean=False)))
    steps.append(("model", build_mlp(num_classes)))
    return Pipeline(steps)


def resolve_target_class(y, target):
    classes = list(pd.Series(y).unique())
    if target in classes:
        return target
    if str(target) in [str(c) for c in classes]:
        for c in classes:
            if str(c) == str(target):
                return c
    print(f"WARN: TARGET_CLASS {target} no esta en clases; se usa {classes[0]}")
    return classes[0]


for balance_name, balancer in BALANCE_METHODS.items():
    print(f"=== Balanceo: {balance_name} ===")
    output_subdir = OUTPUT_PATH / balance_name
    output_subdir.mkdir(parents=True, exist_ok=True)

    for x_file in variantes_X:
        base_name = x_file.replace("X_train_", "").replace(".parquet", "")
        try:
            print(f"Procesando: {base_name}")

            # Cargar datos
            X_train = pd.read_parquet(INPUT_PATH / f"X_train_{base_name}.parquet")
            X_test = pd.read_parquet(INPUT_PATH / f"X_test_{base_name}.parquet")
            y_train = pd.read_parquet(INPUT_PATH / f"y_train_{base_name}.parquet").squeeze()
            y_test = pd.read_parquet(INPUT_PATH / f"y_test_{base_name}.parquet").squeeze()

            nan_total_train = int(X_train.isna().sum().sum())
            nan_total_test = int(X_test.isna().sum().sum())
            if nan_total_train > 0 or nan_total_test > 0:
                print(f"  NaN - train: {nan_total_train}, test: {nan_total_test}")

            if pd.Series(y_train).nunique() < 2:
                print("  Dataset con una sola clase en train; se omite.")
                continue

            target_val = TARGET_CLASS if TARGET_CLASS is not None else pd.Series(y_train).min()
            target_class = resolve_target_class(y_train, target_val)

            # Ajustar etiquetas para MLP (deben empezar en 0)
            y_min = y_train.min()
            y_train_adj = y_train - y_min
            y_test_adj = y_test - y_min
            target_class_adj = target_class - y_min
            num_classes = int(pd.Series(y_train_adj).nunique())

            # CV en train (sin tocar test)
            cv = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=42)
            model_cv = build_pipeline(balancer, num_classes)

            target_scorer = make_scorer(
                recall_score,
                labels=[target_class_adj],
                average="macro",
                zero_division=0
            )
            scorers = {
                "recall_target": target_scorer,
                "f1_macro": "f1_macro"
            }
            cv_results = cross_validate(
                model_cv,
                X_train,
                y_train_adj,
                cv=cv,
                scoring=scorers
            )

            cv_recall_scores = cv_results["test_recall_target"]
            cv_macro_f1_scores = cv_results["test_f1_macro"]
            cv_recall_target = float(np.mean(cv_recall_scores))
            cv_macro_f1 = float(np.mean(cv_macro_f1_scores))

            df_cv = pd.DataFrame({
                "fold": range(1, len(cv_recall_scores) + 1),
                "cv_recall_target": cv_recall_scores,
                "cv_macro_f1": cv_macro_f1_scores,
                "nan_total_train": [nan_total_train] * len(cv_recall_scores),
                "nan_total_test": [nan_total_test] * len(cv_recall_scores)
            })
            df_cv.to_csv(output_subdir / f"cv_metricas_{base_name}.csv", index=False)

            resumen_cv = {
                "modelo": base_name,
                "balanceo": balance_name,
                "cv_recall_target": cv_recall_target,
                "cv_macro_f1": cv_macro_f1,
                "nan_total_train": nan_total_train,
                "nan_total_test": nan_total_test
            }
            metricas_totales.append(resumen_cv)

            if (cv_recall_target > best_score) or (cv_recall_target == best_score and cv_macro_f1 > (best_info.get("cv_macro_f1", -1.0) if best_info else -1.0)):
                best_score = cv_recall_target
                best_info = {
                    "balanceo": balance_name,
                    "base_name": base_name,
                    "cv_recall_target": cv_recall_target,
                    "cv_macro_f1": cv_macro_f1
                }

            print(f"  CV recall clase {target_class}: {cv_recall_target:.3f} | CV macro F1: {cv_macro_f1:.3f}")

        except Exception as e:
            print(f" Error en {base_name} con balanceo {balance_name}: {e}")


if best_info is None:
    raise RuntimeError("No se pudo seleccionar un modelo ganador; revisa los logs.")

print(f"\nMejor modelo por CV (recall clase {TARGET_CLASS}): {best_info}")

# Entrenar y evaluar SOLO el ganador en test
balance_name = best_info["balanceo"]
base_name = best_info["base_name"]
balancer = BALANCE_METHODS[balance_name]

output_subdir = OUTPUT_PATH / balance_name
output_subdir.mkdir(parents=True, exist_ok=True)

X_train = pd.read_parquet(INPUT_PATH / f"X_train_{base_name}.parquet")
X_test = pd.read_parquet(INPUT_PATH / f"X_test_{base_name}.parquet")
y_train = pd.read_parquet(INPUT_PATH / f"y_train_{base_name}.parquet").squeeze()
y_test = pd.read_parquet(INPUT_PATH / f"y_test_{base_name}.parquet").squeeze()

y_min = y_train.min()
y_train_adj = y_train - y_min
y_test_adj = y_test - y_min
num_classes = int(pd.Series(y_train_adj).nunique())

start = time.time()
model = build_pipeline(balancer, num_classes)
model.fit(X_train, y_train_adj)
tiempo = (time.time() - start) / 60

y_pred_train_adj = model.predict(X_train)
y_pred_test_adj = model.predict(X_test)
y_proba = model.predict_proba(X_test)

y_pred_train = y_pred_train_adj + y_min
y_pred_test = y_pred_test_adj + y_min

class_order_adj = model.named_steps["model"].classes_
class_order = class_order_adj + y_min

report_test = pd.DataFrame(classification_report(y_test, y_pred_test, output_dict=True, zero_division=0)).T
report_train = pd.DataFrame(classification_report(y_train, y_pred_train, output_dict=True, zero_division=0)).T
report_test["set"] = "test"
report_train["set"] = "train"
full_report = pd.concat([report_train, report_test])
full_report["tiempo_min"] = tiempo
full_report.to_csv(output_subdir / f"metricas_{base_name}_BEST.csv")

cm = confusion_matrix(y_test, y_pred_test, labels=class_order)
with PdfPages(output_subdir / f"reporte_{base_name}_BEST.pdf") as pdf:
    ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_order).plot(cmap="Blues")
    plt.title("Matriz de Confusion")
    pdf.savefig(); plt.close()

    if np.unique(y_test).size >= 2:
        y_bin = label_binarize(y_test_adj, classes=class_order_adj)
        if y_bin.shape[1] == 1:
            y_bin = np.hstack([1 - y_bin, y_bin])
        proba_for_curves = y_proba
        if proba_for_curves.shape[1] == 1:
            proba_for_curves = np.hstack([1 - y_proba, y_proba])

        plt.figure()
        for i, clase in enumerate(class_order):
            fpr, tpr, _ = roc_curve(y_bin[:, i], proba_for_curves[:, i])
            roc_auc = auc(fpr, tpr)
            plt.plot(fpr, tpr, label=f"Clase {clase} (AUC={roc_auc:.2f})")
        plt.plot([0, 1], [0, 1], "k--")
        plt.title("Curvas ROC por clase")
        plt.xlabel("FPR")
        plt.ylabel("TPR")
        plt.legend()
        pdf.savefig(); plt.close()

        plt.figure()
        for i, clase in enumerate(class_order):
            precision, recall, _ = precision_recall_curve(y_bin[:, i], proba_for_curves[:, i])
            pr_auc = average_precision_score(y_bin[:, i], proba_for_curves[:, i])
            plt.plot(recall, precision, label=f"Clase {clase} (PR AUC={pr_auc:.2f})")
        plt.title("Curvas Precision-Recall por clase")
        plt.xlabel("Recall")
        plt.ylabel("Precision")
        plt.legend()
        pdf.savefig(); plt.close()
    else:
        print("  Test con 1 clase; se omiten curvas ROC/PR.")

resumen = {
    "modelo": base_name,
    "balanceo": balance_name,
    "accuracy_test": accuracy_score(y_test, y_pred_test),
    "macro_f1_test": report_test.loc["macro avg", "f1-score"],
    "weighted_f1_test": report_test.loc["weighted avg", "f1-score"],
    "accuracy_train": accuracy_score(y_train, y_pred_train),
    "macro_f1_train": report_train.loc["macro avg", "f1-score"],
    "weighted_f1_train": report_train.loc["weighted avg", "f1-score"],
    "tiempo_min": tiempo,
    "sobreajuste_macro_f1": report_train.loc["macro avg", "f1-score"] - report_test.loc["macro avg", "f1-score"],
    "cv_recall_target": best_info["cv_recall_target"],
    "cv_macro_f1": best_info["cv_macro_f1"]
}
for clase in report_test.index:
    if clase not in ["accuracy", "macro avg", "weighted avg"]:
        resumen[f"f1_{clase}_test"] = report_test.loc[clase, "f1-score"]
        resumen[f"recall_{clase}_test"] = report_test.loc[clase, "recall"]
        resumen[f"precision_{clase}_test"] = report_test.loc[clase, "precision"]
        resumen[f"f1_{clase}_train"] = report_train.loc[clase, "f1-score"]
        resumen[f"recall_{clase}_train"] = report_train.loc[clase, "recall"]
        resumen[f"precision_{clase}_train"] = report_train.loc[clase, "precision"]

metricas_totales.append(resumen)
print(f"\nBEST {base_name} [{balance_name}]: recall_target_cv={best_info['cv_recall_target']:.3f}, F1_macro_test={resumen.get('macro_f1_test', 0):.3f}")

# Consolidar todas las metricas en un CSV unico
if metricas_totales:
    df_metricas = pd.DataFrame(metricas_totales)
    df_metricas.to_csv(OUTPUT_PATH / "resumen_modelos_redmlp.csv", index=False)
    print(f"Se guardo resumen_modelos_redmlp.csv con {len(df_metricas)} filas en {OUTPUT_PATH}")
    display(df_metricas.head())
else:
    print("No se genero ninguna metrica; revisa los logs de arriba.")
# Out:
# === Balanceo: NONE ===
# Procesando: MaxAbs_FE_ALL
#   CV recall clase 1: 0.048 | CV macro F1: 0.385
# Procesando: MaxAbs_FE_ANOVA
#   CV recall clase 1: 0.000 | CV macro F1: 0.236
# Procesando: MaxAbs_FE_MI
#   CV recall clase 1: 0.000 | CV macro F1: 0.272
# Procesando: MaxAbs_FE_PCA30
#   CV recall clase 1: 0.015 | CV macro F1: 0.352
# Procesando: MaxAbs_FE_PCAopt
#   CV recall clase 1: 0.045 | CV macro F1: 0.386
# Procesando: MaxAbs_FE_VAR
#   CV recall clase 1: 0.003 | CV macro F1: 0.352
# Procesando: MaxAbs_ORIGINAL_ALL
#   CV recall clase 1: 0.055 | CV macro F1: 0.383
# Procesando: MaxAbs_ORIGINAL_ANOVA
#   CV recall clase 1: 0.000 | CV macro F1: 0.304
# Procesando: MaxAbs_ORIGINAL_MI
#   CV recall clase 1: 0.000 | CV macro F1: 0.286
# Procesando: MaxAbs_ORIGINAL_PCA30
#   CV recall clase 1: 0.009 | CV macro F1: 0.345
# Procesando: MaxAbs_ORIGINAL_PCAopt
#   CV recall clase 1: 0.036 | CV macro F1: 0.381
# Procesando: MaxAbs_ORIGINAL_VAR
#   CV recall clase 1: 0.000 | CV macro F1: 0.307
# Procesando: MinMax_FE_ALL
#   CV recall clase 1: 0.045 | CV macro F1: 0.389
# Procesando: MinMax_FE_ANOVA
#   CV recall clase 1: 0.000 | CV macro F1: 0.236
# Procesando: MinMax_FE_MI
#   CV recall clase 1: 0.000 | CV macro F1: 0.277
# Procesando: MinMax_FE_PCA30
#   CV recall clase 1: 0.001 | CV macro F1: 0.353
# Procesando: MinMax_FE_PCAopt
#   CV recall clase 1: 0.051 | CV macro F1: 0.395
# Procesando: MinMax_FE_VAR
#   CV recall clase 1: 0.001 | CV macro F1: 0.354
# Procesando: MinMax_ORIGINAL_ALL
#   CV recall clase 1: 0.048 | CV macro F1: 0.387
# Procesando: MinMax_ORIGINAL_ANOVA
#   CV recall clase 1: 0.000 | CV macro F1: 0.303
# Procesando: MinMax_ORIGINAL_CHI2
#   CV recall clase 1: 0.000 | CV macro F1: 0.272
# Procesando: MinMax_ORIGINAL_MI
#   CV recall clase 1: 0.000 | CV macro F1: 0.288
# Procesando: MinMax_ORIGINAL_PCA30
#   CV recall clase 1: 0.026 | CV macro F1: 0.360
# Procesando: MinMax_ORIGINAL_PCAopt
#   CV recall clase 1: 0.050 | CV macro F1: 0.399
# Procesando: MinMax_ORIGINAL_VAR
#   CV recall clase 1: 0.001 | CV macro F1: 0.303
# Procesando: NoNorm_FE_ALL
#   NaN - train: 0, test: 112098
#   CV recall clase 1: 0.042 | CV macro F1: 0.382
# Procesando: NoNorm_FE_ANOVA
#   CV recall clase 1: 0.021 | CV macro F1: 0.337
# Procesando: NoNorm_FE_MI
#   CV recall clase 1: 0.000 | CV macro F1: 0.270
# Procesando: NoNorm_FE_VAR
#   NaN - train: 0, test: 112098
#   CV recall clase 1: 0.000 | CV macro F1: 0.345
# Procesando: NoNorm_ORIGINAL_ALL
#   CV recall clase 1: 0.055 | CV macro F1: 0.383
# Procesando: NoNorm_ORIGINAL_ANOVA
#   CV recall clase 1: 0.000 | CV macro F1: 0.304
# Procesando: NoNorm_ORIGINAL_MI
#   CV recall clase 1: 0.000 | CV macro F1: 0.289
# Procesando: NoNorm_ORIGINAL_PCA30
#   CV recall clase 1: 0.026 | CV macro F1: 0.360
# Procesando: NoNorm_ORIGINAL_PCAopt
#   CV recall clase 1: 0.050 | CV macro F1: 0.399
# Procesando: NoNorm_ORIGINAL_VAR
#   CV recall clase 1: 0.000 | CV macro F1: 0.340
# Procesando: Robust_FE_ALL
#   CV recall clase 1: 0.055 | CV macro F1: 0.387
# Procesando: Robust_FE_ANOVA
#   CV recall clase 1: 0.000 | CV macro F1: 0.237
# Procesando: Robust_FE_MI
#   CV recall clase 1: 0.000 | CV macro F1: 0.274
# Procesando: Robust_FE_PCA30
#   CV recall clase 1: 0.016 | CV macro F1: 0.353
# Procesando: Robust_FE_PCAopt
#   CV recall clase 1: 0.051 | CV macro F1: 0.389
# Procesando: Robust_FE_VAR
#   CV recall clase 1: 0.009 | CV macro F1: 0.358
# Procesando: Robust_ORIGINAL_ALL
#   CV recall clase 1: 0.049 | CV macro F1: 0.389
# Procesando: Robust_ORIGINAL_ANOVA
#   CV recall clase 1: 0.001 | CV macro F1: 0.310
# Procesando: Robust_ORIGINAL_MI
#   CV recall clase 1: 0.001 | CV macro F1: 0.291
# Procesando: Robust_ORIGINAL_PCA30
#   CV recall clase 1: 0.026 | CV macro F1: 0.360
# Procesando: Robust_ORIGINAL_PCAopt
#   CV recall clase 1: 0.050 | CV macro F1: 0.399
# Procesando: Robust_ORIGINAL_VAR
#   CV recall clase 1: 0.001 | CV macro F1: 0.344
# Procesando: Standard_FE_ALL
#   CV recall clase 1: 0.053 | CV macro F1: 0.392
# Procesando: Standard_FE_ANOVA
#   CV recall clase 1: 0.000 | CV macro F1: 0.281
# Procesando: Standard_FE_MI
#   CV recall clase 1: 0.000 | CV macro F1: 0.285
# Procesando: Standard_FE_PCA30
#   CV recall clase 1: 0.024 | CV macro F1: 0.351
# Procesando: Standard_FE_PCAopt
#   CV recall clase 1: 0.046 | CV macro F1: 0.387
# Procesando: Standard_FE_VAR
#   CV recall clase 1: 0.032 | CV macro F1: 0.383
# Procesando: Standard_ORIGINAL_ALL
#   CV recall clase 1: 0.048 | CV macro F1: 0.398
# Procesando: Standard_ORIGINAL_ANOVA
#   CV recall clase 1: 0.001 | CV macro F1: 0.308
# Procesando: Standard_ORIGINAL_MI
#   CV recall clase 1: 0.000 | CV macro F1: 0.301
# Procesando: Standard_ORIGINAL_PCA30
#   CV recall clase 1: 0.026 | CV macro F1: 0.360
# Procesando: Standard_ORIGINAL_PCAopt
#   CV recall clase 1: 0.050 | CV macro F1: 0.399
# Procesando: Standard_ORIGINAL_VAR
#   CV recall clase 1: 0.048 | CV macro F1: 0.398
# === Balanceo: SMOTE ===
# Procesando: MaxAbs_FE_ALL
#   CV recall clase 1: 0.257 | CV macro F1: 0.425
# Procesando: MaxAbs_FE_ANOVA
#   CV recall clase 1: 0.575 | CV macro F1: 0.242
# Procesando: MaxAbs_FE_MI
#   CV recall clase 1: 0.498 | CV macro F1: 0.291
# Procesando: MaxAbs_FE_PCA30
# c:\Users\Gonzalo\Documents\GitHub\TesisAustral\tesis_austral_2\.venv\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (60) reached and the optimization hasn't converged yet.
#   warnings.warn(
#   CV recall clase 1: 0.360 | CV macro F1: 0.384
# Procesando: MaxAbs_FE_PCAopt
#   CV recall clase 1: 0.255 | CV macro F1: 0.412
# Procesando: MaxAbs_FE_VAR
#   CV recall clase 1: 0.188 | CV macro F1: 0.395
# Procesando: MaxAbs_ORIGINAL_ALL
#   CV recall clase 1: 0.252 | CV macro F1: 0.407
# Procesando: MaxAbs_ORIGINAL_ANOVA
#   CV recall clase 1: 0.401 | CV macro F1: 0.345
# Procesando: MaxAbs_ORIGINAL_MI
#   CV recall clase 1: 0.446 | CV macro F1: 0.312
# Procesando: MaxAbs_ORIGINAL_PCA30
#   CV recall clase 1: 0.358 | CV macro F1: 0.383
# Procesando: MaxAbs_ORIGINAL_PCAopt
#   CV recall clase 1: 0.278 | CV macro F1: 0.407
# Procesando: MaxAbs_ORIGINAL_VAR
#   CV recall clase 1: 0.204 | CV macro F1: 0.341
# Procesando: MinMax_FE_ALL
#   CV recall clase 1: 0.364 | CV macro F1: 0.398
# Procesando: MinMax_FE_ANOVA
#   CV recall clase 1: 0.501 | CV macro F1: 0.258
# Procesando: MinMax_FE_MI
#   CV recall clase 1: 0.538 | CV macro F1: 0.298
# Procesando: MinMax_FE_PCA30
#   CV recall clase 1: 0.367 | CV macro F1: 0.388
# Procesando: MinMax_FE_PCAopt
#   CV recall clase 1: 0.264 | CV macro F1: 0.408
# Procesando: MinMax_FE_VAR
#   CV recall clase 1: 0.194 | CV macro F1: 0.387
# Procesando: MinMax_ORIGINAL_ALL
#   CV recall clase 1: 0.230 | CV macro F1: 0.413
# Procesando: MinMax_ORIGINAL_ANOVA
#   CV recall clase 1: 0.395 | CV macro F1: 0.342
# Procesando: MinMax_ORIGINAL_CHI2
#   CV recall clase 1: 0.508 | CV macro F1: 0.300
# Procesando: MinMax_ORIGINAL_MI
#   CV recall clase 1: 0.373 | CV macro F1: 0.334
# Procesando: MinMax_ORIGINAL_PCA30
#   CV recall clase 1: 0.341 | CV macro F1: 0.385
# Procesando: MinMax_ORIGINAL_PCAopt
#   CV recall clase 1: 0.286 | CV macro F1: 0.411
# Procesando: MinMax_ORIGINAL_VAR
#   CV recall clase 1: 0.194 | CV macro F1: 0.339
# Procesando: NoNorm_FE_ALL
#   NaN - train: 0, test: 112098
#   CV recall clase 1: 0.413 | CV macro F1: 0.403
# Procesando: NoNorm_FE_ANOVA
#   CV recall clase 1: 0.176 | CV macro F1: 0.369
# Procesando: NoNorm_FE_MI
#   CV recall clase 1: 0.364 | CV macro F1: 0.302
# Procesando: NoNorm_FE_VAR
#   NaN - train: 0, test: 112098
#   CV recall clase 1: 0.353 | CV macro F1: 0.389
# Procesando: NoNorm_ORIGINAL_ALL
#   CV recall clase 1: 0.075 | CV macro F1: 0.395
# Procesando: NoNorm_ORIGINAL_ANOVA
#   CV recall clase 1: 0.233 | CV macro F1: 0.341
# Procesando: NoNorm_ORIGINAL_MI
#   CV recall clase 1: 0.231 | CV macro F1: 0.332
# Procesando: NoNorm_ORIGINAL_PCA30
#   CV recall clase 1: 0.341 | CV macro F1: 0.385
# Procesando: NoNorm_ORIGINAL_PCAopt
#   CV recall clase 1: 0.287 | CV macro F1: 0.411
# Procesando: NoNorm_ORIGINAL_VAR
#   CV recall clase 1: 0.118 | CV macro F1: 0.359
# Procesando: Robust_FE_ALL
#   CV recall clase 1: 0.231 | CV macro F1: 0.417
# Procesando: Robust_FE_ANOVA
#   CV recall clase 1: 0.472 | CV macro F1: 0.264
# Procesando: Robust_FE_MI
#   CV recall clase 1: 0.488 | CV macro F1: 0.294
# Procesando: Robust_FE_PCA30
#   CV recall clase 1: 0.346 | CV macro F1: 0.390
# Procesando: Robust_FE_PCAopt
#   CV recall clase 1: 0.266 | CV macro F1: 0.407
# Procesando: Robust_FE_VAR
#   CV recall clase 1: 0.217 | CV macro F1: 0.399
# Procesando: Robust_ORIGINAL_ALL
#   CV recall clase 1: 0.211 | CV macro F1: 0.416
# Procesando: Robust_ORIGINAL_ANOVA
#   CV recall clase 1: 0.229 | CV macro F1: 0.350
# Procesando: Robust_ORIGINAL_MI
#   CV recall clase 1: 0.286 | CV macro F1: 0.333
# Procesando: Robust_ORIGINAL_PCA30
#   CV recall clase 1: 0.341 | CV macro F1: 0.385
# Procesando: Robust_ORIGINAL_PCAopt
#   CV recall clase 1: 0.286 | CV macro F1: 0.406
# Procesando: Robust_ORIGINAL_VAR
#   CV recall clase 1: 0.179 | CV macro F1: 0.378
# Procesando: Standard_FE_ALL
#   CV recall clase 1: 0.297 | CV macro F1: 0.413
# Procesando: Standard_FE_ANOVA
#   CV recall clase 1: 0.523 | CV macro F1: 0.294
# Procesando: Standard_FE_MI
#   CV recall clase 1: 0.422 | CV macro F1: 0.316
# Procesando: Standard_FE_PCA30
#   CV recall clase 1: 0.397 | CV macro F1: 0.385
# Procesando: Standard_FE_PCAopt
#   CV recall clase 1: 0.272 | CV macro F1: 0.415
# Procesando: Standard_FE_VAR
#   CV recall clase 1: 0.271 | CV macro F1: 0.412
# Procesando: Standard_ORIGINAL_ALL
#   CV recall clase 1: 0.274 | CV macro F1: 0.406
# Procesando: Standard_ORIGINAL_ANOVA
#   CV recall clase 1: 0.357 | CV macro F1: 0.343
# Procesando: Standard_ORIGINAL_MI
#   CV recall clase 1: 0.358 | CV macro F1: 0.340
# Procesando: Standard_ORIGINAL_PCA30
#   CV recall clase 1: 0.341 | CV macro F1: 0.385
# Procesando: Standard_ORIGINAL_PCAopt
#   CV recall clase 1: 0.293 | CV macro F1: 0.412
# Procesando: Standard_ORIGINAL_VAR
#   CV recall clase 1: 0.274 | CV macro F1: 0.406
# === Balanceo: UNDER ===
# Procesando: MaxAbs_FE_ALL
#   CV recall clase 1: 0.092 | CV macro F1: 0.410
# Procesando: MaxAbs_FE_ANOVA
#   CV recall clase 1: 0.255 | CV macro F1: 0.270
# Procesando: MaxAbs_FE_MI
#   CV recall clase 1: 0.271 | CV macro F1: 0.291
# Procesando: MaxAbs_FE_PCA30
#   CV recall clase 1: 0.273 | CV macro F1: 0.381
# Procesando: MaxAbs_FE_PCAopt
#   CV recall clase 1: 0.153 | CV macro F1: 0.409
# Procesando: MaxAbs_FE_VAR
#   CV recall clase 1: 0.352 | CV macro F1: 0.392
# Procesando: MaxAbs_ORIGINAL_ALL
#   CV recall clase 1: 0.229 | CV macro F1: 0.419
# Procesando: MaxAbs_ORIGINAL_ANOVA
#   CV recall clase 1: 0.380 | CV macro F1: 0.334
# Procesando: MaxAbs_ORIGINAL_MI
#   CV recall clase 1: 0.318 | CV macro F1: 0.303
# Procesando: MaxAbs_ORIGINAL_PCA30
#   CV recall clase 1: 0.245 | CV macro F1: 0.389
# Procesando: MaxAbs_ORIGINAL_PCAopt
#   CV recall clase 1: 0.293 | CV macro F1: 0.411
# Procesando: MaxAbs_ORIGINAL_VAR
#   CV recall clase 1: 0.484 | CV macro F1: 0.330
# Procesando: MinMax_FE_ALL
#   CV recall clase 1: 0.343 | CV macro F1: 0.408
# Procesando: MinMax_FE_ANOVA
#   CV recall clase 1: 0.359 | CV macro F1: 0.269
# Procesando: MinMax_FE_MI
#   CV recall clase 1: 0.352 | CV macro F1: 0.306
# Procesando: MinMax_FE_PCA30
#   CV recall clase 1: 0.265 | CV macro F1: 0.391
# Procesando: MinMax_FE_PCAopt
#   CV recall clase 1: 0.337 | CV macro F1: 0.403
# Procesando: MinMax_FE_VAR
#   CV recall clase 1: 0.274 | CV macro F1: 0.405
# Procesando: MinMax_ORIGINAL_ALL
#   CV recall clase 1: 0.250 | CV macro F1: 0.410
# Procesando: MinMax_ORIGINAL_ANOVA
#   CV recall clase 1: 0.347 | CV macro F1: 0.346
# Procesando: MinMax_ORIGINAL_CHI2
#   CV recall clase 1: 0.398 | CV macro F1: 0.310
# Procesando: MinMax_ORIGINAL_MI
#   CV recall clase 1: 0.284 | CV macro F1: 0.316
# Procesando: MinMax_ORIGINAL_PCA30
#   CV recall clase 1: 0.279 | CV macro F1: 0.386
# Procesando: MinMax_ORIGINAL_PCAopt
#   CV recall clase 1: 0.286 | CV macro F1: 0.418
# Procesando: MinMax_ORIGINAL_VAR
#   CV recall clase 1: 0.346 | CV macro F1: 0.345
# Procesando: NoNorm_FE_ALL
#   NaN - train: 0, test: 112098
#   CV recall clase 1: 0.104 | CV macro F1: 0.398
# Procesando: NoNorm_FE_ANOVA
#   CV recall clase 1: 0.293 | CV macro F1: 0.354
# Procesando: NoNorm_FE_MI
#   CV recall clase 1: 0.246 | CV macro F1: 0.288
# Procesando: NoNorm_FE_VAR
#   NaN - train: 0, test: 112098
#   CV recall clase 1: 0.354 | CV macro F1: 0.386
# Procesando: NoNorm_ORIGINAL_ALL
#   CV recall clase 1: 0.229 | CV macro F1: 0.419
# Procesando: NoNorm_ORIGINAL_ANOVA
#   CV recall clase 1: 0.380 | CV macro F1: 0.334
# Procesando: NoNorm_ORIGINAL_MI
#   CV recall clase 1: 0.163 | CV macro F1: 0.310
# Procesando: NoNorm_ORIGINAL_PCA30
#   CV recall clase 1: 0.279 | CV macro F1: 0.386
# Procesando: NoNorm_ORIGINAL_PCAopt
#   CV recall clase 1: 0.286 | CV macro F1: 0.418
# Procesando: NoNorm_ORIGINAL_VAR
#   CV recall clase 1: 0.377 | CV macro F1: 0.362
# Procesando: Robust_FE_ALL
#   CV recall clase 1: 0.376 | CV macro F1: 0.414
# Procesando: Robust_FE_ANOVA
#   CV recall clase 1: 0.375 | CV macro F1: 0.275
# Procesando: Robust_FE_MI
#   CV recall clase 1: 0.247 | CV macro F1: 0.309
# Procesando: Robust_FE_PCA30
#   CV recall clase 1: 0.286 | CV macro F1: 0.395
# Procesando: Robust_FE_PCAopt
#   CV recall clase 1: 0.283 | CV macro F1: 0.424
# Procesando: Robust_FE_VAR
#   CV recall clase 1: 0.441 | CV macro F1: 0.385
# Procesando: Robust_ORIGINAL_ALL
#   CV recall clase 1: 0.261 | CV macro F1: 0.407
# Procesando: Robust_ORIGINAL_ANOVA
#   CV recall clase 1: 0.321 | CV macro F1: 0.347
# Procesando: Robust_ORIGINAL_MI
#   CV recall clase 1: 0.431 | CV macro F1: 0.323
# Procesando: Robust_ORIGINAL_PCA30
#   CV recall clase 1: 0.279 | CV macro F1: 0.386
# Procesando: Robust_ORIGINAL_PCAopt
#   CV recall clase 1: 0.286 | CV macro F1: 0.418
# Procesando: Robust_ORIGINAL_VAR
#   CV recall clase 1: 0.380 | CV macro F1: 0.374
# Procesando: Standard_FE_ALL
#   CV recall clase 1: 0.379 | CV macro F1: 0.418
# Procesando: Standard_FE_ANOVA
#   CV recall clase 1: 0.320 | CV macro F1: 0.306
# Procesando: Standard_FE_MI
#   CV recall clase 1: 0.374 | CV macro F1: 0.319
# Procesando: Standard_FE_PCA30
#   CV recall clase 1: 0.286 | CV macro F1: 0.389
# Procesando: Standard_FE_PCAopt
#   CV recall clase 1: 0.369 | CV macro F1: 0.412
# Procesando: Standard_FE_VAR
#   CV recall clase 1: 0.207 | CV macro F1: 0.414
# Procesando: Standard_ORIGINAL_ALL
#   CV recall clase 1: 0.307 | CV macro F1: 0.406
# Procesando: Standard_ORIGINAL_ANOVA
#   CV recall clase 1: 0.329 | CV macro F1: 0.347
# Procesando: Standard_ORIGINAL_MI
#   CV recall clase 1: 0.380 | CV macro F1: 0.331
# Procesando: Standard_ORIGINAL_PCA30
#   CV recall clase 1: 0.279 | CV macro F1: 0.386
# Procesando: Standard_ORIGINAL_PCAopt
#   CV recall clase 1: 0.286 | CV macro F1: 0.418
# Procesando: Standard_ORIGINAL_VAR
#   CV recall clase 1: 0.307 | CV macro F1: 0.406
# === Balanceo: SMOTEENN ===
# Procesando: MaxAbs_FE_ALL
#   CV recall clase 1: 0.912 | CV macro F1: 0.286
# Procesando: MaxAbs_FE_ANOVA
#   CV recall clase 1: 0.084 | CV macro F1: 0.264
# Procesando: MaxAbs_FE_MI
#   CV recall clase 1: 0.317 | CV macro F1: 0.305
# Procesando: MaxAbs_FE_PCA30
#   CV recall clase 1: 0.723 | CV macro F1: 0.316
# Procesando: MaxAbs_FE_PCAopt
#   CV recall clase 1: 0.497 | CV macro F1: 0.381
# Procesando: MaxAbs_FE_VAR
#   CV recall clase 1: 0.531 | CV macro F1: 0.354
# Procesando: MaxAbs_ORIGINAL_ALL
#   CV recall clase 1: 0.714 | CV macro F1: 0.344
# Procesando: MaxAbs_ORIGINAL_ANOVA
# c:\Users\Gonzalo\Documents\GitHub\TesisAustral\tesis_austral_2\.venv\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (60) reached and the optimization hasn't converged yet.
#   warnings.warn(
#   CV recall clase 1: 0.735 | CV macro F1: 0.279
# Procesando: MaxAbs_ORIGINAL_MI
#   CV recall clase 1: 0.914 | CV macro F1: 0.206
# Procesando: MaxAbs_ORIGINAL_PCA30
#   CV recall clase 1: 0.716 | CV macro F1: 0.316
# Procesando: MaxAbs_ORIGINAL_PCAopt
#   CV recall clase 1: 0.487 | CV macro F1: 0.379
# Procesando: MaxAbs_ORIGINAL_VAR
#   CV recall clase 1: 0.556 | CV macro F1: 0.299
# Procesando: MinMax_FE_ALL
#   CV recall clase 1: 0.723 | CV macro F1: 0.351
# Procesando: MinMax_FE_ANOVA
#   CV recall clase 1: 0.067 | CV macro F1: 0.263
# Procesando: MinMax_FE_MI
#   CV recall clase 1: 0.633 | CV macro F1: 0.267
# Procesando: MinMax_FE_PCA30
#   CV recall clase 1: 0.736 | CV macro F1: 0.316
# Procesando: MinMax_FE_PCAopt
# c:\Users\Gonzalo\Documents\GitHub\TesisAustral\tesis_austral_2\.venv\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (60) reached and the optimization hasn't converged yet.
#   warnings.warn(
#   CV recall clase 1: 0.493 | CV macro F1: 0.381
# Procesando: MinMax_FE_VAR
#   CV recall clase 1: 0.532 | CV macro F1: 0.352
# Procesando: MinMax_ORIGINAL_ALL
#   CV recall clase 1: 0.581 | CV macro F1: 0.360
# Procesando: MinMax_ORIGINAL_ANOVA
#   CV recall clase 1: 0.685 | CV macro F1: 0.292
# Procesando: MinMax_ORIGINAL_CHI2
#   CV recall clase 1: 0.562 | CV macro F1: 0.241
# Procesando: MinMax_ORIGINAL_MI
#   CV recall clase 1: 0.886 | CV macro F1: 0.222
# Procesando: MinMax_ORIGINAL_PCA30
#   CV recall clase 1: 0.711 | CV macro F1: 0.317
# Procesando: MinMax_ORIGINAL_PCAopt
#   CV recall clase 1: 0.488 | CV macro F1: 0.378
# Procesando: MinMax_ORIGINAL_VAR
#   CV recall clase 1: 0.541 | CV macro F1: 0.302
# Procesando: NoNorm_FE_ALL
#   NaN - train: 0, test: 112098
#   CV recall clase 1: 0.892 | CV macro F1: 0.297
# Procesando: NoNorm_FE_ANOVA
#   CV recall clase 1: 0.829 | CV macro F1: 0.276
# Procesando: NoNorm_FE_MI
# c:\Users\Gonzalo\Documents\GitHub\TesisAustral\tesis_austral_2\.venv\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (60) reached and the optimization hasn't converged yet.
#   warnings.warn(
#   CV recall clase 1: 0.097 | CV macro F1: 0.304
# Procesando: NoNorm_FE_VAR
#   NaN - train: 0, test: 112098
#   CV recall clase 1: 0.890 | CV macro F1: 0.267
# Procesando: NoNorm_ORIGINAL_ALL
#   CV recall clase 1: 0.844 | CV macro F1: 0.311
# Procesando: NoNorm_ORIGINAL_ANOVA
#   CV recall clase 1: 0.758 | CV macro F1: 0.271
# Procesando: NoNorm_ORIGINAL_MI
#   CV recall clase 1: 0.924 | CV macro F1: 0.198
# Procesando: NoNorm_ORIGINAL_PCA30
#   CV recall clase 1: 0.711 | CV macro F1: 0.317
# Procesando: NoNorm_ORIGINAL_PCAopt
#   CV recall clase 1: 0.493 | CV macro F1: 0.378
# Procesando: NoNorm_ORIGINAL_VAR
#   CV recall clase 1: 0.873 | CV macro F1: 0.251
# Procesando: Robust_FE_ALL
#   CV recall clase 1: 0.508 | CV macro F1: 0.371
# Procesando: Robust_FE_ANOVA
#   CV recall clase 1: 0.103 | CV macro F1: 0.265
# Procesando: Robust_FE_MI
#   CV recall clase 1: 0.503 | CV macro F1: 0.292
# Procesando: Robust_FE_PCA30
#   CV recall clase 1: 0.714 | CV macro F1: 0.331
# Procesando: Robust_FE_PCAopt
#   CV recall clase 1: 0.518 | CV macro F1: 0.380
# Procesando: Robust_FE_VAR
#   CV recall clase 1: 0.527 | CV macro F1: 0.348
# Procesando: Robust_ORIGINAL_ALL
#   CV recall clase 1: 0.534 | CV macro F1: 0.358
# Procesando: Robust_ORIGINAL_ANOVA
#   CV recall clase 1: 0.585 | CV macro F1: 0.304
# Procesando: Robust_ORIGINAL_MI
#   CV recall clase 1: 0.717 | CV macro F1: 0.272
# Procesando: Robust_ORIGINAL_PCA30
#   CV recall clase 1: 0.711 | CV macro F1: 0.317
# Procesando: Robust_ORIGINAL_PCAopt
#   CV recall clase 1: 0.491 | CV macro F1: 0.377
# Procesando: Robust_ORIGINAL_VAR
#   CV recall clase 1: 0.560 | CV macro F1: 0.317
# Procesando: Standard_FE_ALL
#   CV recall clase 1: 0.500 | CV macro F1: 0.389
# Procesando: Standard_FE_ANOVA
#   CV recall clase 1: 0.511 | CV macro F1: 0.291
# Procesando: Standard_FE_MI
# c:\Users\Gonzalo\Documents\GitHub\TesisAustral\tesis_austral_2\.venv\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (60) reached and the optimization hasn't converged yet.
#   warnings.warn(
# c:\Users\Gonzalo\Documents\GitHub\TesisAustral\tesis_austral_2\.venv\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (60) reached and the optimization hasn't converged yet.
#   warnings.warn(
#   CV recall clase 1: 0.495 | CV macro F1: 0.303
# Procesando: Standard_FE_PCA30
#   CV recall clase 1: 0.753 | CV macro F1: 0.321
# Procesando: Standard_FE_PCAopt
# c:\Users\Gonzalo\Documents\GitHub\TesisAustral\tesis_austral_2\.venv\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (60) reached and the optimization hasn't converged yet.
#   warnings.warn(
#   CV recall clase 1: 0.501 | CV macro F1: 0.380
# Procesando: Standard_FE_VAR
#   CV recall clase 1: 0.499 | CV macro F1: 0.389
# Procesando: Standard_ORIGINAL_ALL
#   CV recall clase 1: 0.488 | CV macro F1: 0.381
# Procesando: Standard_ORIGINAL_ANOVA
# c:\Users\Gonzalo\Documents\GitHub\TesisAustral\tesis_austral_2\.venv\Lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (60) reached and the optimization hasn't converged yet.
#   warnings.warn(
#   CV recall clase 1: 0.527 | CV macro F1: 0.313
# Procesando: Standard_ORIGINAL_MI
#   CV recall clase 1: 0.640 | CV macro F1: 0.297
# Procesando: Standard_ORIGINAL_PCA30
#   CV recall clase 1: 0.711 | CV macro F1: 0.317
# Procesando: Standard_ORIGINAL_PCAopt
#   CV recall clase 1: 0.482 | CV macro F1: 0.379
# Procesando: Standard_ORIGINAL_VAR
#   CV recall clase 1: 0.488 | CV macro F1: 0.381
#
# Mejor modelo por CV (recall clase None): {'balanceo': 'SMOTEENN', 'base_name': 'NoNorm_ORIGINAL_MI', 'cv_recall_target': 0.9237145197821791, 'cv_macro_f1': 0.19753821872976762}
#
# BEST NoNorm_ORIGINAL_MI [SMOTEENN]: recall_target_cv=0.924, F1_macro_test=0.203
# Se guardo resumen_modelos_redmlp.csv con 237 filas en C:\Users\Gonzalo\Documents\GitHub\TesisAustral\tesis_austral_2\reports\10_modelo_redmlp\20260221\RedMLP_10_2026-02-21
#              modelo balanceo  cv_recall_target  cv_macro_f1  nan_total_train  \
# 0     MaxAbs_FE_ALL     NONE          0.048190     0.384925              0.0
# 1   MaxAbs_FE_ANOVA     NONE          0.000000     0.235589              0.0
# 2      MaxAbs_FE_MI     NONE          0.000000     0.271969              0.0
# 3   MaxAbs_FE_PCA30     NONE          0.015204     0.352181              0.0
# 4  MaxAbs_FE_PCAopt     NONE          0.044986     0.385971              0.0
#
#    nan_total_test  accuracy_test  macro_f1_test  weighted_f1_test  \
# 0             0.0            NaN            NaN               NaN
# 1             0.0            NaN            NaN               NaN
# 2             0.0            NaN            NaN               NaN
# 3             0.0            NaN            NaN               NaN
# 4             0.0            NaN            NaN               NaN
#
#    accuracy_train  ...  precision_4_test  f1_4_train  recall_4_train  \
# 0             NaN  ...               NaN         NaN             NaN
# 1             NaN  ...               NaN         NaN             NaN
# 2             NaN  ...               NaN         NaN             NaN
# 3             NaN  ...               NaN         NaN             NaN
# 4             NaN  ...               NaN         NaN             NaN
#
#    precision_4_train  f1_5_test  recall_5_test  precision_5_test  f1_5_train  \
# 0                NaN        NaN            NaN               NaN         NaN
# 1                NaN        NaN            NaN               NaN         NaN
# 2                NaN        NaN            NaN               NaN         NaN
# 3                NaN        NaN            NaN               NaN         NaN
# 4                NaN        NaN            NaN               NaN         NaN
#
#    recall_5_train  precision_5_train
# 0             NaN                NaN
# 1             NaN                NaN
# 2             NaN                NaN
# 3             NaN                NaN
# 4             NaN                NaN
#
# [5 rows x 44 columns]
