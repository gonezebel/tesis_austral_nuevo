# %%
import os
import time
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from lightgbm import LGBMClassifier
from sklearn.metrics import (
    classification_report, confusion_matrix, ConfusionMatrixDisplay,
    roc_curve, auc, accuracy_score, precision_recall_curve, average_precision_score,
    recall_score, make_scorer
)
from sklearn.preprocessing import label_binarize
from matplotlib.backends.backend_pdf import PdfPages
from datetime import datetime
from pathlib import Path
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import RandomUnderSampler
from imblearn.combine import SMOTEENN
from imblearn.pipeline import Pipeline
from sklearn.model_selection import StratifiedKFold, cross_validate

# %%
# === CONFIGURACION ===
REPO_ROOT = Path(".").resolve()
RUN_ID = datetime.today().strftime("%Y%m%d")

INPUT_BASE = REPO_ROOT / "data" / "intermediate" / "05_seleccion_v2"
OUTPUT_BASE = REPO_ROOT / "reports" / "09_modelo_lightgbm_v2" / RUN_ID
RESUME_OUTPUT_PATH = REPO_ROOT / "reports" / "09_modelo_lightgbm_v2" / "20260424" / "LightGBM_v2_01_2026-04-24"
ONLY_TARGETS = ["5_vs_resto"]  # usar ["5_vs_resto"] cuando quieras correr solo target 5

MODEL_NAME = "LightGBM_v2"
INTENTO = 3
N_SPLITS = 3
TARGET_CLASS = 1  # clase positiva; la clase nula es 0
N_ESTIMATORS = 180
LEARNING_RATE = 0.05
fecha_actual = datetime.today().strftime("%Y-%m-%d")

if not INPUT_BASE.exists():
    raise FileNotFoundError("No se encontro data/intermediate/05_seleccion_v2")

input_candidates = sorted([p for p in INPUT_BASE.iterdir() if p.is_dir()])
if not input_candidates:
    raise FileNotFoundError("No se encontraron subcarpetas en data/intermediate/05_seleccion_v2")
INPUT_PATH = input_candidates[-1]
print(f"Usando input: {INPUT_PATH}")

TARGET_DIRS = sorted([p.name for p in INPUT_PATH.iterdir() if p.is_dir()])
if ONLY_TARGETS:
    missing_targets = sorted(set(ONLY_TARGETS) - set(TARGET_DIRS))
    if missing_targets:
        raise FileNotFoundError(f"Targets pedidos no existen en {INPUT_PATH}: {missing_targets}")
    TARGET_DIRS = ONLY_TARGETS
if not TARGET_DIRS:
    raise FileNotFoundError(f"No se encontraron targets dentro de {INPUT_PATH}")
print(f"Targets detectados: {TARGET_DIRS}")

OUTPUT_PATH = RESUME_OUTPUT_PATH if RESUME_OUTPUT_PATH.exists() else OUTPUT_BASE / f"{MODEL_NAME}_{INTENTO:02d}_{fecha_actual}"
if RESUME_OUTPUT_PATH.exists():
    print(f"Modo resume: usando output existente {OUTPUT_PATH}")
OUTPUT_PATH.mkdir(parents=True, exist_ok=True)

BALANCE_METHODS = {
    "NONE": None,
    "SMOTE": SMOTE(random_state=42),
    "UNDER": RandomUnderSampler(random_state=42),
    "SMOTEENN": SMOTEENN(random_state=42)
}

metricas_totales = []
# Out:
# Usando input: C:\Users\Gonzalo\Documents\GitHub\TesisAustral\tesis_austral_2\data\intermediate\05_seleccion_v2\05_2026_03_31
# Targets detectados: ['5_vs_resto']
# Modo resume: usando output existente C:\Users\Gonzalo\Documents\GitHub\TesisAustral\tesis_austral_2\reports\09_modelo_lightgbm_v2\20260424\LightGBM_v2_01_2026-04-24

# %%
def build_lgbm(num_classes: int):
    "Modelo liviano para multi/binary clase."
    params = dict(
        boosting_type="gbdt",
        objective="multiclass" if num_classes > 2 else "binary",
        n_estimators=N_ESTIMATORS,
        learning_rate=LEARNING_RATE,
        num_leaves=31,
        max_depth=-1,
        subsample=0.85,
        colsample_bytree=0.9,
        max_bin=63,
        min_child_samples=20,
        reg_alpha=0.1,
        reg_lambda=1.0,
        bagging_freq=1,
        n_jobs=-1,
        random_state=42,
    )
    if num_classes > 2:
        params["num_class"] = num_classes
    return LGBMClassifier(**params)


def build_pipeline(balancer, num_classes: int):
    steps = []
    if balancer is not None:
        steps.append(("balance", balancer))
    steps.append(("model", build_lgbm(num_classes)))
    return Pipeline(steps)


def resolve_target_class(y, target):
    classes = list(pd.Series(y).unique())
    if target in classes:
        return target
    if str(target) in [str(c) for c in classes]:
        for c in classes:
            if str(c) == str(target):
                return c
    raise ValueError(f"TARGET_CLASS {target} no esta en clases disponibles: {classes}")


for target_name in TARGET_DIRS:
    print(f"\n===== Target: {target_name} =====")
    target_input_path = INPUT_PATH / target_name
    target_output_path = OUTPUT_PATH / target_name
    target_output_path.mkdir(parents=True, exist_ok=True)

    variantes_X = sorted([f.name for f in target_input_path.iterdir() if f.is_file() and f.name.startswith("X_train_")])
    print(f"Se detectaron {len(variantes_X)} variantes de X_train_* en {target_input_path}")
    if not variantes_X:
        print("  No hay variantes para procesar; se omite target.")
        continue

    best_score = -1.0
    best_info = None
    metricas_target = []

    for balance_name, balancer in BALANCE_METHODS.items():
        print(f"=== Balanceo: {balance_name} ===")
        output_subdir = target_output_path / balance_name
        output_subdir.mkdir(parents=True, exist_ok=True)

        for x_file in variantes_X:
            base_name = x_file.replace("X_train_", "").replace(".parquet", "")
            try:
                print(f"Procesando: {base_name}")
                cv_path = output_subdir / f"cv_metricas_{base_name}.csv"
                if cv_path.exists():
                    df_cv = pd.read_csv(cv_path)
                    cv_recall_target = float(df_cv["cv_recall_target"].mean())
                    cv_macro_f1 = float(df_cv["cv_macro_f1"].mean())
                    target_class = df_cv["target_class"].iloc[0] if "target_class" in df_cv.columns else TARGET_CLASS
                    target_class_adj = df_cv["target_class_adj"].iloc[0] if "target_class_adj" in df_cv.columns else TARGET_CLASS
                    nan_total_train = int(df_cv["nan_total_train"].iloc[0]) if "nan_total_train" in df_cv.columns else 0
                    nan_total_test = int(df_cv["nan_total_test"].iloc[0]) if "nan_total_test" in df_cv.columns else 0
                    resumen_cv = {
                        "target": target_name,
                        "modelo": base_name,
                        "balanceo": balance_name,
                        "target_class": target_class,
                        "target_class_adj": target_class_adj,
                        "cv_recall_target": cv_recall_target,
                        "cv_macro_f1": cv_macro_f1,
                        "nan_total_train": nan_total_train,
                        "nan_total_test": nan_total_test
                    }
                    metricas_target.append(resumen_cv)
                    metricas_totales.append(resumen_cv)
                    if (cv_recall_target > best_score) or (cv_recall_target == best_score and cv_macro_f1 > (best_info.get("cv_macro_f1", -1.0) if best_info else -1.0)):
                        best_score = cv_recall_target
                        best_info = {
                            "target": target_name,
                            "balanceo": balance_name,
                            "base_name": base_name,
                            "target_class": target_class,
                            "target_class_adj": target_class_adj,
                            "cv_recall_target": cv_recall_target,
                            "cv_macro_f1": cv_macro_f1
                        }
                    print(f"  Reusado CV existente: recall clase {target_class}: {cv_recall_target:.3f} | CV macro F1: {cv_macro_f1:.3f}")
                    continue


                X_train = pd.read_parquet(target_input_path / f"X_train_{base_name}.parquet")
                X_test = pd.read_parquet(target_input_path / f"X_test_{base_name}.parquet")
                y_train = pd.read_parquet(target_input_path / f"y_train_{base_name}.parquet").squeeze()
                y_test = pd.read_parquet(target_input_path / f"y_test_{base_name}.parquet").squeeze()

                nan_total_train = int(X_train.isna().sum().sum())
                nan_total_test = int(X_test.isna().sum().sum())
                if nan_total_train > 0 or nan_total_test > 0:
                    print(f"  NaN - train: {nan_total_train}, test: {nan_total_test}")

                if pd.Series(y_train).nunique() < 2:
                    print("  Dataset con una sola clase en train; se omite.")
                    continue

                target_class = resolve_target_class(y_train, TARGET_CLASS)

                y_min = y_train.min()
                y_train_adj = y_train - y_min
                y_test_adj = y_test - y_min
                target_class_adj = target_class - y_min
                num_classes = int(pd.Series(y_train_adj).nunique())

                cv = StratifiedKFold(n_splits=N_SPLITS, shuffle=True, random_state=42)
                model_cv = build_pipeline(balancer, num_classes)

                target_scorer = make_scorer(
                    recall_score,
                    labels=[target_class_adj],
                    average="macro",
                    zero_division=0
                )
                scorers = {
                    "recall_target": target_scorer,
                    "f1_macro": "f1_macro"
                }
                cv_results = cross_validate(
                    model_cv,
                    X_train,
                    y_train_adj,
                    cv=cv,
                    scoring=scorers
                )

                cv_recall_scores = cv_results["test_recall_target"]
                cv_macro_f1_scores = cv_results["test_f1_macro"]
                cv_recall_target = float(np.mean(cv_recall_scores))
                cv_macro_f1 = float(np.mean(cv_macro_f1_scores))

                df_cv = pd.DataFrame({
                    "target": target_name,
                    "fold": range(1, len(cv_recall_scores) + 1),
                    "cv_recall_target": cv_recall_scores,
                    "cv_macro_f1": cv_macro_f1_scores,
                    "nan_total_train": [nan_total_train] * len(cv_recall_scores),
                    "nan_total_test": [nan_total_test] * len(cv_recall_scores),
                    "target_class": [target_class] * len(cv_recall_scores),
                    "target_class_adj": [target_class_adj] * len(cv_recall_scores)
                })
                df_cv.to_csv(output_subdir / f"cv_metricas_{base_name}.csv", index=False)

                resumen_cv = {
                    "target": target_name,
                    "modelo": base_name,
                    "balanceo": balance_name,
                    "target_class": target_class,
                    "target_class_adj": target_class_adj,
                    "cv_recall_target": cv_recall_target,
                    "cv_macro_f1": cv_macro_f1,
                    "nan_total_train": nan_total_train,
                    "nan_total_test": nan_total_test
                }
                metricas_target.append(resumen_cv)
                metricas_totales.append(resumen_cv)

                if (cv_recall_target > best_score) or (cv_recall_target == best_score and cv_macro_f1 > (best_info.get("cv_macro_f1", -1.0) if best_info else -1.0)):
                    best_score = cv_recall_target
                    best_info = {
                        "target": target_name,
                        "balanceo": balance_name,
                        "base_name": base_name,
                        "target_class": target_class,
                        "target_class_adj": target_class_adj,
                        "cv_recall_target": cv_recall_target,
                        "cv_macro_f1": cv_macro_f1
                    }

                print(f"  CV recall clase {target_class}: {cv_recall_target:.3f} | CV macro F1: {cv_macro_f1:.3f}")

            except Exception as e:
                print(f" Error en {base_name} con balanceo {balance_name}: {e}")

    if best_info is None:
        print(f"No se pudo seleccionar un modelo ganador para {target_name}; revisa los logs.")
        continue

    print(f"\nMejor modelo por CV para {target_name} (recall clase {best_info['target_class']}): {best_info}")

    balance_name = best_info["balanceo"]
    base_name = best_info["base_name"]
    balancer = BALANCE_METHODS[balance_name]

    output_subdir = target_output_path / balance_name
    output_subdir.mkdir(parents=True, exist_ok=True)

    X_train = pd.read_parquet(target_input_path / f"X_train_{base_name}.parquet")
    X_test = pd.read_parquet(target_input_path / f"X_test_{base_name}.parquet")
    y_train = pd.read_parquet(target_input_path / f"y_train_{base_name}.parquet").squeeze()
    y_test = pd.read_parquet(target_input_path / f"y_test_{base_name}.parquet").squeeze()

    y_min = y_train.min()
    y_train_adj = y_train - y_min
    y_test_adj = y_test - y_min
    num_classes = int(pd.Series(y_train_adj).nunique())

    start = time.time()
    model = build_pipeline(balancer, num_classes)
    model.fit(X_train, y_train_adj)
    tiempo = (time.time() - start) / 60

    y_pred_train_adj = model.predict(X_train)
    y_pred_test_adj = model.predict(X_test)
    y_proba = model.predict_proba(X_test)

    y_pred_train = y_pred_train_adj + y_min
    y_pred_test = y_pred_test_adj + y_min

    class_order_adj = model.named_steps["model"].classes_
    class_order = class_order_adj + y_min

    report_test = pd.DataFrame(classification_report(y_test, y_pred_test, output_dict=True, zero_division=0)).T
    report_train = pd.DataFrame(classification_report(y_train, y_pred_train, output_dict=True, zero_division=0)).T
    report_test["set"] = "test"
    report_train["set"] = "train"
    full_report = pd.concat([report_train, report_test])
    full_report["tiempo_min"] = tiempo
    full_report["target"] = target_name
    full_report.to_csv(output_subdir / f"metricas_{base_name}_BEST.csv")

    cm = confusion_matrix(y_test, y_pred_test, labels=class_order)
    with PdfPages(output_subdir / f"reporte_{base_name}_BEST.pdf") as pdf:
        ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_order).plot(cmap="Blues")
        plt.title(f"Matriz de Confusion - {target_name}")
        pdf.savefig(); plt.close()

        if np.unique(y_test).size >= 2:
            y_bin = label_binarize(y_test_adj, classes=class_order_adj)
            if y_bin.shape[1] == 1:
                y_bin = np.hstack([1 - y_bin, y_bin])
            proba_for_curves = y_proba
            if proba_for_curves.shape[1] == 1:
                proba_for_curves = np.hstack([1 - y_proba, y_proba])

            plt.figure()
            for i, clase in enumerate(class_order):
                fpr, tpr, _ = roc_curve(y_bin[:, i], proba_for_curves[:, i])
                roc_auc = auc(fpr, tpr)
                plt.plot(fpr, tpr, label=f"Clase {clase} (AUC={roc_auc:.2f})")
            plt.plot([0, 1], [0, 1], "k--")
            plt.title(f"Curvas ROC por clase - {target_name}")
            plt.xlabel("FPR")
            plt.ylabel("TPR")
            plt.legend()
            pdf.savefig(); plt.close()

            plt.figure()
            for i, clase in enumerate(class_order):
                precision, recall, _ = precision_recall_curve(y_bin[:, i], proba_for_curves[:, i])
                pr_auc = average_precision_score(y_bin[:, i], proba_for_curves[:, i])
                plt.plot(recall, precision, label=f"Clase {clase} (PR AUC={pr_auc:.2f})")
            plt.title(f"Curvas Precision-Recall por clase - {target_name}")
            plt.xlabel("Recall")
            plt.ylabel("Precision")
            plt.legend()
            pdf.savefig(); plt.close()
        else:
            print("  Test con 1 clase; se omiten curvas ROC/PR.")

    resumen = {
        "target": target_name,
        "modelo": base_name,
        "balanceo": balance_name,
        "target_class": best_info["target_class"],
        "target_class_adj": best_info["target_class_adj"],
        "accuracy_test": accuracy_score(y_test, y_pred_test),
        "macro_f1_test": report_test.loc["macro avg", "f1-score"],
        "weighted_f1_test": report_test.loc["weighted avg", "f1-score"],
        "accuracy_train": accuracy_score(y_train, y_pred_train),
        "macro_f1_train": report_train.loc["macro avg", "f1-score"],
        "weighted_f1_train": report_train.loc["weighted avg", "f1-score"],
        "tiempo_min": tiempo,
        "sobreajuste_macro_f1": report_train.loc["macro avg", "f1-score"] - report_test.loc["macro avg", "f1-score"],
        "cv_recall_target": best_info["cv_recall_target"],
        "cv_macro_f1": best_info["cv_macro_f1"]
    }
    for clase in report_test.index:
        if clase not in ["accuracy", "macro avg", "weighted avg"]:
            resumen[f"f1_{clase}_test"] = report_test.loc[clase, "f1-score"]
            resumen[f"recall_{clase}_test"] = report_test.loc[clase, "recall"]
            resumen[f"precision_{clase}_test"] = report_test.loc[clase, "precision"]
            resumen[f"f1_{clase}_train"] = report_train.loc[clase, "f1-score"]
            resumen[f"recall_{clase}_train"] = report_train.loc[clase, "recall"]
            resumen[f"precision_{clase}_train"] = report_train.loc[clase, "precision"]

    metricas_target.append(resumen)
    metricas_totales.append(resumen)
    print(f"\nBEST {target_name} | {base_name} [{balance_name}]: recall_target_cv={best_info['cv_recall_target']:.3f}, F1_macro_test={resumen.get('macro_f1_test', 0):.3f}")

    df_metricas_target = pd.DataFrame(metricas_target)
    df_metricas_target.to_csv(target_output_path / "resumen_modelos_lightgbm.csv", index=False)
    print(f"Se guardo resumen_modelos_lightgbm.csv con {len(df_metricas_target)} filas en {target_output_path}")

# Consolidar todas las metricas en un CSV unico
if metricas_totales:
    df_metricas = pd.DataFrame(metricas_totales)
    df_metricas.to_csv(OUTPUT_PATH / "resumen_modelos_lightgbm_global.csv", index=False)
    print(f"Se guardo resumen_modelos_lightgbm_global.csv con {len(df_metricas)} filas en {OUTPUT_PATH}")
    display(df_metricas.head())
else:
    print("No se genero ninguna metrica; revisa los logs de arriba.")
# Out:
# ===== Target: 5_vs_resto =====
# Se detectaron 59 variantes de X_train_* en C:\Users\Gonzalo\Documents\GitHub\TesisAustral\tesis_austral_2\data\intermediate\05_seleccion_v2\05_2026_03_31\5_vs_resto
# === Balanceo: NONE ===
# Procesando: MaxAbs_FE_ALL
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82907, number of negative: 216018
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.428048 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 14859
# [LightGBM] [Info] Number of data points in the train set: 298925, number of used features: 1202
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277351 -> initscore=-0.957642
# [LightGBM] [Info] Start training from score -0.957642
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82907, number of negative: 216018
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.683702 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 14825
# [LightGBM] [Info] Number of data points in the train set: 298925, number of used features: 1203
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277351 -> initscore=-0.957642
# [LightGBM] [Info] Start training from score -0.957642
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82908, number of negative: 216018
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.683844 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 14854
# [LightGBM] [Info] Number of data points in the train set: 298926, number of used features: 1203
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277353 -> initscore=-0.957630
# [LightGBM] [Info] Start training from score -0.957630
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
#   CV recall clase 1: 0.749 | CV macro F1: 0.841
# Procesando: MaxAbs_FE_ANOVA
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82907, number of negative: 216018
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.026306 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 668
# [LightGBM] [Info] Number of data points in the train set: 298925, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277351 -> initscore=-0.957642
# [LightGBM] [Info] Start training from score -0.957642
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82907, number of negative: 216018
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013065 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 664
# [LightGBM] [Info] Number of data points in the train set: 298925, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277351 -> initscore=-0.957642
# [LightGBM] [Info] Start training from score -0.957642
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82908, number of negative: 216018
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.017529 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 667
# [LightGBM] [Info] Number of data points in the train set: 298926, number of used features: 21
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277353 -> initscore=-0.957630
# [LightGBM] [Info] Start training from score -0.957630
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
#   CV recall clase 1: 0.296 | CV macro F1: 0.630
# Procesando: MaxAbs_FE_MI
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82907, number of negative: 216018
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011636 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 69
# [LightGBM] [Info] Number of data points in the train set: 298925, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277351 -> initscore=-0.957642
# [LightGBM] [Info] Start training from score -0.957642
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82907, number of negative: 216018
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013710 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 69
# [LightGBM] [Info] Number of data points in the train set: 298925, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277351 -> initscore=-0.957642
# [LightGBM] [Info] Start training from score -0.957642
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82908, number of negative: 216018
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013002 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 69
# [LightGBM] [Info] Number of data points in the train set: 298926, number of used features: 14
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277353 -> initscore=-0.957630
# [LightGBM] [Info] Start training from score -0.957630
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
#   CV recall clase 1: 0.260 | CV macro F1: 0.609
# Procesando: MaxAbs_FE_PCA30
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82907, number of negative: 216018
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.027152 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1890
# [LightGBM] [Info] Number of data points in the train set: 298925, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277351 -> initscore=-0.957642
# [LightGBM] [Info] Start training from score -0.957642
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82907, number of negative: 216018
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.027881 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1890
# [LightGBM] [Info] Number of data points in the train set: 298925, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277351 -> initscore=-0.957642
# [LightGBM] [Info] Start training from score -0.957642
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82908, number of negative: 216018
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.026745 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1890
# [LightGBM] [Info] Number of data points in the train set: 298926, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277353 -> initscore=-0.957630
# [LightGBM] [Info] Start training from score -0.957630
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
#   CV recall clase 1: 0.620 | CV macro F1: 0.767
# Procesando: MaxAbs_FE_PCAopt
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82907, number of negative: 216018
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.500676 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 30492
# [LightGBM] [Info] Number of data points in the train set: 298925, number of used features: 484
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277351 -> initscore=-0.957642
# [LightGBM] [Info] Start training from score -0.957642
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82907, number of negative: 216018
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.507825 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 30492
# [LightGBM] [Info] Number of data points in the train set: 298925, number of used features: 484
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277351 -> initscore=-0.957642
# [LightGBM] [Info] Start training from score -0.957642
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82908, number of negative: 216018
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.517045 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 30492
# [LightGBM] [Info] Number of data points in the train set: 298926, number of used features: 484
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277353 -> initscore=-0.957630
# [LightGBM] [Info] Start training from score -0.957630
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
#   CV recall clase 1: 0.699 | CV macro F1: 0.826
# Procesando: MaxAbs_FE_VAR
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82907, number of negative: 216018
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.144593 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4871
# [LightGBM] [Info] Number of data points in the train set: 298925, number of used features: 387
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277351 -> initscore=-0.957642
# [LightGBM] [Info] Start training from score -0.957642
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82907, number of negative: 216018
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.166465 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 4857
# [LightGBM] [Info] Number of data points in the train set: 298925, number of used features: 387
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277351 -> initscore=-0.957642
# [LightGBM] [Info] Start training from score -0.957642
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82908, number of negative: 216018
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.243829 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 4857
# [LightGBM] [Info] Number of data points in the train set: 298926, number of used features: 387
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277353 -> initscore=-0.957630
# [LightGBM] [Info] Start training from score -0.957630
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
#   CV recall clase 1: 0.725 | CV macro F1: 0.815
# Procesando: MaxAbs_ORIGINAL_ALL
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82907, number of negative: 216018
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.202753 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 3376
# [LightGBM] [Info] Number of data points in the train set: 298925, number of used features: 553
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277351 -> initscore=-0.957642
# [LightGBM] [Info] Start training from score -0.957642
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82907, number of negative: 216018
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.258932 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3372
# [LightGBM] [Info] Number of data points in the train set: 298925, number of used features: 554
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277351 -> initscore=-0.957642
# [LightGBM] [Info] Start training from score -0.957642
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82908, number of negative: 216018
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.248778 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3377
# [LightGBM] [Info] Number of data points in the train set: 298926, number of used features: 554
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277353 -> initscore=-0.957630
# [LightGBM] [Info] Start training from score -0.957630
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
#   CV recall clase 1: 0.751 | CV macro F1: 0.841
# Procesando: MaxAbs_ORIGINAL_ANOVA
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82907, number of negative: 216018
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.008213 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 77
# [LightGBM] [Info] Number of data points in the train set: 298925, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277351 -> initscore=-0.957642
# [LightGBM] [Info] Start training from score -0.957642
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82907, number of negative: 216018
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.009828 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 77
# [LightGBM] [Info] Number of data points in the train set: 298925, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277351 -> initscore=-0.957642
# [LightGBM] [Info] Start training from score -0.957642
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82908, number of negative: 216018
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.011360 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 77
# [LightGBM] [Info] Number of data points in the train set: 298926, number of used features: 8
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277353 -> initscore=-0.957630
# [LightGBM] [Info] Start training from score -0.957630
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
#   CV recall clase 1: 0.263 | CV macro F1: 0.609
# Procesando: MaxAbs_ORIGINAL_MI
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82907, number of negative: 216018
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.029847 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1134
# [LightGBM] [Info] Number of data points in the train set: 298925, number of used features: 54
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277351 -> initscore=-0.957642
# [LightGBM] [Info] Start training from score -0.957642
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82907, number of negative: 216018
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.030221 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1125
# [LightGBM] [Info] Number of data points in the train set: 298925, number of used features: 54
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277351 -> initscore=-0.957642
# [LightGBM] [Info] Start training from score -0.957642
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82908, number of negative: 216018
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.031037 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1125
# [LightGBM] [Info] Number of data points in the train set: 298926, number of used features: 54
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277353 -> initscore=-0.957630
# [LightGBM] [Info] Start training from score -0.957630
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
#   CV recall clase 1: 0.518 | CV macro F1: 0.720
# Procesando: MaxAbs_ORIGINAL_PCA30
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82907, number of negative: 216018
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.026909 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1890
# [LightGBM] [Info] Number of data points in the train set: 298925, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277351 -> initscore=-0.957642
# [LightGBM] [Info] Start training from score -0.957642
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82907, number of negative: 216018
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.027936 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1890
# [LightGBM] [Info] Number of data points in the train set: 298925, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277351 -> initscore=-0.957642
# [LightGBM] [Info] Start training from score -0.957642
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82908, number of negative: 216018
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.028160 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1890
# [LightGBM] [Info] Number of data points in the train set: 298926, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277353 -> initscore=-0.957630
# [LightGBM] [Info] Start training from score -0.957630
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
#   CV recall clase 1: 0.546 | CV macro F1: 0.754
# Procesando: MaxAbs_ORIGINAL_PCAopt
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82907, number of negative: 216018
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.591783 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 30303
# [LightGBM] [Info] Number of data points in the train set: 298925, number of used features: 481
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277351 -> initscore=-0.957642
# [LightGBM] [Info] Start training from score -0.957642
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82907, number of negative: 216018
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.517925 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 30303
# [LightGBM] [Info] Number of data points in the train set: 298925, number of used features: 481
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277351 -> initscore=-0.957642
# [LightGBM] [Info] Start training from score -0.957642
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82908, number of negative: 216018
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.509462 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 30303
# [LightGBM] [Info] Number of data points in the train set: 298926, number of used features: 481
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277353 -> initscore=-0.957630
# [LightGBM] [Info] Start training from score -0.957630
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
#   CV recall clase 1: 0.666 | CV macro F1: 0.816
# Procesando: MaxAbs_ORIGINAL_VAR
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82907, number of negative: 216018
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.080768 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 392
# [LightGBM] [Info] Number of data points in the train set: 298925, number of used features: 163
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277351 -> initscore=-0.957642
# [LightGBM] [Info] Start training from score -0.957642
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82907, number of negative: 216018
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.066749 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 391
# [LightGBM] [Info] Number of data points in the train set: 298925, number of used features: 163
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277351 -> initscore=-0.957642
# [LightGBM] [Info] Start training from score -0.957642
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82908, number of negative: 216018
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.063380 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 392
# [LightGBM] [Info] Number of data points in the train set: 298926, number of used features: 163
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277353 -> initscore=-0.957630
# [LightGBM] [Info] Start training from score -0.957630
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
#   CV recall clase 1: 0.561 | CV macro F1: 0.740
# Procesando: MinMax_FE_ALL
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82907, number of negative: 216018
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.641476 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 13305
# [LightGBM] [Info] Number of data points in the train set: 298925, number of used features: 1173
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277351 -> initscore=-0.957642
# [LightGBM] [Info] Start training from score -0.957642
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82907, number of negative: 216018
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.776462 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 13280
# [LightGBM] [Info] Number of data points in the train set: 298925, number of used features: 1174
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277351 -> initscore=-0.957642
# [LightGBM] [Info] Start training from score -0.957642
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82908, number of negative: 216018
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.613488 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 13301
# [LightGBM] [Info] Number of data points in the train set: 298926, number of used features: 1174
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277353 -> initscore=-0.957630
# [LightGBM] [Info] Start training from score -0.957630
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
#   CV recall clase 1: 0.750 | CV macro F1: 0.841
# Procesando: MinMax_FE_ANOVA
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82907, number of negative: 216018
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.016126 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 583
# [LightGBM] [Info] Number of data points in the train set: 298925, number of used features: 19
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277351 -> initscore=-0.957642
# [LightGBM] [Info] Start training from score -0.957642
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82907, number of negative: 216018
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.013767 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 583
# [LightGBM] [Info] Number of data points in the train set: 298925, number of used features: 19
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277351 -> initscore=-0.957642
# [LightGBM] [Info] Start training from score -0.957642
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82908, number of negative: 216018
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.014370 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 583
# [LightGBM] [Info] Number of data points in the train set: 298926, number of used features: 19
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277353 -> initscore=-0.957630
# [LightGBM] [Info] Start training from score -0.957630
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
#   CV recall clase 1: 0.249 | CV macro F1: 0.609
# Procesando: MinMax_FE_MI
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82907, number of negative: 216018
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.019373 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 428
# [LightGBM] [Info] Number of data points in the train set: 298925, number of used features: 32
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277351 -> initscore=-0.957642
# [LightGBM] [Info] Start training from score -0.957642
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82907, number of negative: 216018
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.021010 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 421
# [LightGBM] [Info] Number of data points in the train set: 298925, number of used features: 32
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277351 -> initscore=-0.957642
# [LightGBM] [Info] Start training from score -0.957642
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82908, number of negative: 216018
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.019252 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 426
# [LightGBM] [Info] Number of data points in the train set: 298926, number of used features: 32
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277353 -> initscore=-0.957630
# [LightGBM] [Info] Start training from score -0.957630
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
#   CV recall clase 1: 0.410 | CV macro F1: 0.676
# Procesando: MinMax_FE_PCA30
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82907, number of negative: 216018
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.028057 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1890
# [LightGBM] [Info] Number of data points in the train set: 298925, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277351 -> initscore=-0.957642
# [LightGBM] [Info] Start training from score -0.957642
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82907, number of negative: 216018
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.027951 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1890
# [LightGBM] [Info] Number of data points in the train set: 298925, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277351 -> initscore=-0.957642
# [LightGBM] [Info] Start training from score -0.957642
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82908, number of negative: 216018
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.034064 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1890
# [LightGBM] [Info] Number of data points in the train set: 298926, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.277353 -> initscore=-0.957630
# [LightGBM] [Info] Start training from score -0.957630
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
#   CV recall clase 1: 0.618 | CV macro F1: 0.764
# Procesando: MinMax_FE_PCAopt
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 82907, number of negative: 216018
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.185198 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 30555
# ...
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
#   CV recall clase 1: 0.282 | CV macro F1: 0.535
# Procesando: Standard_ORIGINAL_PCA30
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 186472, number of negative: 113185
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.027296 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1890
# [LightGBM] [Info] Number of data points in the train set: 299657, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.622285 -> initscore=0.499257
# [LightGBM] [Info] Start training from score 0.499257
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 186399, number of negative: 113016
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.026258 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1890
# [LightGBM] [Info] Number of data points in the train set: 299415, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.622544 -> initscore=0.500360
# [LightGBM] [Info] Start training from score 0.500360
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 186567, number of negative: 112876
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.026941 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 1890
# [LightGBM] [Info] Number of data points in the train set: 299443, number of used features: 30
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.623047 -> initscore=0.502501
# [LightGBM] [Info] Start training from score 0.502501
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
#   CV recall clase 1: 0.873 | CV macro F1: 0.699
# Procesando: Standard_ORIGINAL_PCAopt
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 193853, number of negative: 124834
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.636028 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 30303
# [LightGBM] [Info] Number of data points in the train set: 318687, number of used features: 481
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.608287 -> initscore=0.440115
# [LightGBM] [Info] Start training from score 0.440115
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 194071, number of negative: 124411
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.598170 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 30303
# [LightGBM] [Info] Number of data points in the train set: 318482, number of used features: 481
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.609363 -> initscore=0.444633
# [LightGBM] [Info] Start training from score 0.444633
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 194277, number of negative: 124182
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.599717 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 30303
# [LightGBM] [Info] Number of data points in the train set: 318459, number of used features: 481
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.610053 -> initscore=0.447537
# [LightGBM] [Info] Start training from score 0.447537
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
#   CV recall clase 1: 0.892 | CV macro F1: 0.786
# Procesando: Standard_ORIGINAL_VAR
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 195023, number of negative: 118724
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.282593 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21437
# [LightGBM] [Info] Number of data points in the train set: 313747, number of used features: 551
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.621593 -> initscore=0.496316
# [LightGBM] [Info] Start training from score 0.496316
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 195220, number of negative: 118303
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.209014 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 21425
# [LightGBM] [Info] Number of data points in the train set: 313523, number of used features: 554
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.622666 -> initscore=0.500878
# [LightGBM] [Info] Start training from score 0.500878
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 195425, number of negative: 118027
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.270192 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 21529
# [LightGBM] [Info] Number of data points in the train set: 313452, number of used features: 552
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.623461 -> initscore=0.504263
# [LightGBM] [Info] Start training from score 0.504263
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
#   CV recall clase 1: 0.888 | CV macro F1: 0.819
#
# Mejor modelo por CV para 5_vs_resto (recall clase 1): {'target': '5_vs_resto', 'balanceo': 'SMOTEENN', 'base_name': 'Robust_ORIGINAL_ALL', 'target_class': 1, 'target_class_adj': np.int64(1), 'cv_recall_target': 0.9197015218244301, 'cv_macro_f1': 0.7496631346364296}
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Info] Number of positive: 288697, number of negative: 92222
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.290234 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 30310
# [LightGBM] [Info] Number of data points in the train set: 380919, number of used features: 554
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.757896 -> initscore=1.141179
# [LightGBM] [Info] Start training from score 1.141179
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
# [LightGBM] [Warning] bagging_freq is set=1, subsample_freq=0 will be ignored. Current value: bagging_freq=1
#
# BEST 5_vs_resto | Robust_ORIGINAL_ALL [SMOTEENN]: recall_target_cv=0.920, F1_macro_test=0.756
# Se guardo resumen_modelos_lightgbm.csv con 237 filas en C:\Users\Gonzalo\Documents\GitHub\TesisAustral\tesis_austral_2\reports\09_modelo_lightgbm_v2\20260424\LightGBM_v2_01_2026-04-24\5_vs_resto
# Se guardo resumen_modelos_lightgbm_global.csv con 237 filas en C:\Users\Gonzalo\Documents\GitHub\TesisAustral\tesis_austral_2\reports\09_modelo_lightgbm_v2\20260424\LightGBM_v2_01_2026-04-24
#        target            modelo balanceo  target_class  target_class_adj  \
# 0  5_vs_resto     MaxAbs_FE_ALL     NONE             1                 1
# 1  5_vs_resto   MaxAbs_FE_ANOVA     NONE             1                 1
# 2  5_vs_resto      MaxAbs_FE_MI     NONE             1                 1
# 3  5_vs_resto   MaxAbs_FE_PCA30     NONE             1                 1
# 4  5_vs_resto  MaxAbs_FE_PCAopt     NONE             1                 1
#
#    cv_recall_target  cv_macro_f1  nan_total_train  nan_total_test  \
# 0          0.748957     0.841076              0.0             0.0
# 1          0.296162     0.629583              0.0             0.0
# 2          0.259864     0.608936              0.0             0.0
# 3          0.619913     0.766955              0.0             0.0
# 4          0.698989     0.825516              0.0             0.0
#
#    accuracy_test  ...  precision_0_test  f1_0_train  recall_0_train  \
# 0            NaN  ...               NaN         NaN             NaN
# 1            NaN  ...               NaN         NaN             NaN
# 2            NaN  ...               NaN         NaN             NaN
# 3            NaN  ...               NaN         NaN             NaN
# 4            NaN  ...               NaN         NaN             NaN
#
#    precision_0_train  f1_1_test  recall_1_test  precision_1_test  f1_1_train  \
# 0                NaN        NaN            NaN               NaN         NaN
# 1                NaN        NaN            NaN               NaN         NaN
# 2                NaN        NaN            NaN               NaN         NaN
# 3                NaN        NaN            NaN               NaN         NaN
# 4                NaN        NaN            NaN               NaN         NaN
#
#    recall_1_train  precision_1_train
# 0             NaN                NaN
# 1             NaN                NaN
# 2             NaN                NaN
# 3             NaN                NaN
# 4             NaN                NaN
#
# [5 rows x 29 columns]
